# %% [markdown]
# # Analysis Report(WeRateDogs Project)
# ## By Niharika Jain
# ### Date: 01/12/22

# %% [markdown]
# In this report, I am going to analyze some data gathered from WeRateDog's Twitter account with Visualization. I am answering the following questions:
#
# ## [Analyze](#analyze)
# >- [Question 1. What is the most retweeted tweet?](#question1)
# >- [Question 2. What is the most common rating?](#question2)
# >- [Question 3. What are the most common breeds found by the neural network?](#question3)
# >- [Question 4. What is the most Popular Twitter Source?](#question4)
# >- [Question 5. Find out Top 5 Average Ratings, Favorite, Retweet Count By Dog Breed](#question5)
#
# ## [Visualization](#visual)
# >- [Visualization 1: What is the average retweet count for each rating?](#visual1)
# >- [Visualization 2 - Top 10 Dog Breed](#visual2)
# >- [Visualization 3 - Which dog breed are most rated](#visual3)
# >- [Visualization 4 - The most favourite dog type?](#visual4)

# %% [markdown]
# ## <a id='analyze'>Analyze</a>

# %% [markdown]
# ## <a id='question1'>Question 1. What is the most retweeted tweet? </a>

# %% [markdown]
# > Most Retweetd **Labrador Retriever** breed with **744234799360020481** tweet id has 71858 retweet count & 146597 favorite count.

# %%
from IPython.display import Image
Image(filename='most_retweeted_twitter_handle.jpg', width=500)

# %% [markdown]
# ## <a id='question2'>Question 2. What is the most common rating? </a>

# %% [markdown]
# >Most common rating is **12** which has given to **433** dogs.

# %% [markdown]
# ## <a id='question3'>Question 3. What are the most common breeds found by the neural network? </a>

# %% [markdown]
# >Most Common Breed is **Golden Retriever** with **128** count.
# ><br>Top 5 common breeds are **'Golden Retriever', 'Pembroke', 'Labrador Retriever', 'Chihuahua', 'Pug'**.

# %% [markdown]
# ## <a id='question4'>Question 4. What is the most Popular Twitter Source? </a>

# %% [markdown]
# >Most Popular Twitter Souce is **Twitter for iPhone** with **1885** count.

# %% [markdown]
# ## <a id='question5'> Question 5. Find out Top 5 Average Ratings, Favorite, Retweet Count By Dog Breed </a>

# %% [markdown]
# >In Top 5 Average Favorite Count is **41788.0** for **Conch** breed.
# ><br>Top 5 Average Favorite Dog Breeds by favorite count are **'Conch', 'Limousine', 'Angora', 'Fountain', 'Bubble'**.

# %% [markdown]
# ## <a id ='visual'>Visualize</a>
#
# For visualization, I used matplot lib libraries and save all charts in the local directory. I created 4 charts and each chart contains some common values so I created a function for common syntaxes.
#
# ```
# def plotGrapgh(title,xlabel,ylabel,xrotation):
#     plt.title(title,size=20)
#     plt.xlabel(xlabel, fontsize=18)
#     plt.ylabel(ylabel, fontsize=18)
#     plt.xticks(rotation=xrotation, fontsize=16)
#     plt.yticks(fontsize=16)
#  ```

# %% [markdown]
# ### <a id ='visual1'>Visualization 1: What is the average retweet count for each rating?</a>

# %%
Image(filename='Dog Rating vs Average Number of Retweets.png', width=700)

# %% [markdown]
# **As per the chart, dogs with a 14 rating have more retweets counts compared to a lower rating. For 14 rating dogs, no of Retweets are 6557 and for 13 rating value is 5274.**

# %% [markdown]
# ### <a id ='visual2'> Visualization 2 - Top 10 Dog Breed </a>

# %%
Image(filename='Top 10 Dog Breed.png', width=700)

# %% [markdown]
# Most common dog breeds are **Golden Retriever, Pembroke, Labrador Retriever, Chihuahua** & **Pug**.

# %% [markdown]
# ### <a id ='visual3'> Visualization 3 - Which dog breed are most rated </a>

# %%
Image(filename='Most rated Dog Breed.png', width=700)

# %% [markdown]
# Most common Dog Breeds as compared to Average Ratings are **Prison, Pedestal, Military Uniform, Limouine** & **Pole.**

# %% [markdown]
# ### <a id ='visual4'> Visualization 4 - The most favourite dog type </a>

# %%
Image(filename='Most Favorite Dog Type.png', width=700)

# %% [markdown]
# **Pupper** is the most favorite dog type with 218 count. **Floofer** is the least favorite one with 3 count only.
